# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from PIL import Image
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 모델

# %%
# GPU 메모리제한
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # 텐서플로가 첫 번째 GPU에 1GB 메모리만 할당하도록 제한
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*7)])
    except RuntimeError as e:
        # 프로그램 시작시에 가상 장치가 설정되어야만 합니다
        print(e)

# %%
# 모델 작성
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Conv3D, MaxPool3D,Flatten, Activation, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.regularizers import l2

model_name = '모델_3_1'

weight_decay = 0.005
num_class = 26
input_shape=(112,112)
channel_num = 3

model = Sequential()
model.add(Conv3D(64,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay),
                 input_shape=input_shape+(frame_num, channel_num)))
model.add(MaxPool3D((2,2,1),strides=(2,2,1),padding='same'))

model.add(Conv3D(128,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Conv3D(256,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(Conv3D(256,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Conv3D(512,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(Conv3D(512,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Conv3D(512,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(Conv3D(512,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Flatten())
model.add(Dense(units=int(4096), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=int(4096), activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_class, activation='softmax'))
model.summary()

model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# 모델 작성_축약
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Conv3D, MaxPool3D,Flatten, Activation, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.regularizers import l2

model_name = '모델2_13'

weight_decay = 0.005
frame_num = 16
num_class = 26
input_shape=(112,112)
channel_num = 3

model = Sequential()
model.add(Conv3D(64,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay),
                 input_shape=input_shape+(frame_num, channel_num)))
model.add(MaxPool3D((2,2,1),strides=(2,2,1),padding='same'))

model.add(Conv3D(128,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))
model.add(Conv3D(128,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Conv3D(256,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Conv3D(256,(3,3,3), strides=(1,1,1), padding='same',
                 activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(MaxPool3D((2,2,2),strides=(2,2,2),padding='same'))

model.add(Flatten())
model.add(Dense(units=int(2048), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=int(2048), activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_class, activation='softmax'))
model.summary()

model.compile(optimizer=RMSprop(learning_rate=1e-4), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 112, 112, 16, 64)  5248
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 56, 56, 16, 64)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 56, 56, 16, 128)   221312
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 28, 28, 8, 128)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 28, 28, 8, 128)    442496
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 14, 14, 4, 128)    0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 14, 14, 4, 256)    884992
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 7, 7, 2, 256)      0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 7, 2, 256)      1769728
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 4, 4, 1, 256)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              8390656
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 26)                53274
# =================================================================
# Total params: 15,964,058
# Trainable params: 15,964,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, rankdir='TB', dpi=96, 
           to_file=f'../data/models/{model_name}.png')

# %%
# 학습
base_dir = '../data/pre'
folder_list = os.listdir(base_dir)

batch_size = 1
shuffle_list = list(range(0,num_class))*batch_size

history_dict = {'acc':list(), 'val_acc':list(), 'loss':list(), 'val_loss':list()}

# early stopping용 변수
loss_f = 100000
count = 0
patience = 20
threshold = 0.0005

for batch in range(int(len(folder_list)/batch_size)):
    batch_x_data = list()
    batch_t_data = list()
    for folder in folder_list[batch*batch_size:(batch+1)*batch_size]:
        for n in range(num_class):
            file_dir = os.path.join(base_dir, (folder+'/'+str(n)))
            file_list = os.listdir(os.path.join(base_dir, (folder+'/'+str(n))))
            temp_data = list()
            a = np.random.normal()/10
            for file in file_list:
                img = cv2.imread(os.path.join(file_dir, file))
                img = np.array(img)
                # 정규화
                img = img/255
                temp_data.append(img)
            temp_data = np.array(temp_data)
            batch_x_data.append(temp_data)
            batch_t_data.append(n)

    # 리스트인 batch_x_data를 ndarray로
    batch_x_data = np.array(batch_x_data)
    batch_t_data = np.array(batch_t_data)

    # 축변경
    batch_x_data = np.swapaxes(batch_x_data,1,2)
    batch_x_data = np.swapaxes(batch_x_data,2,3)

    # data shuffle
    random.shuffle(shuffle_list)

    batch_x_data = batch_x_data[shuffle_list]
    batch_t_data = batch_t_data[shuffle_list]

    # one_hot_encording
    batch_t_data = np.array(batch_t_data)
    batch_t_data = pd.DataFrame(batch_t_data, columns=['t'])
    batch_t_data = pd.get_dummies(batch_t_data['t'])
    
    # learning
    history = model.fit(x=batch_x_data, y=batch_t_data.values, epochs=3, verbose=1, validation_split=0.3)    
    history_dict['acc'].append(history.history['accuracy']) 
    history_dict['val_acc'].append(history.history['val_accuracy'])
    
    history_dict['loss'].append(history.history['loss'])
    history_dict['val_loss'].append(history.history['val_loss'])
    
    
    # early stopping구현
    loss_r = np.mean(history.history['loss'])
    if loss_f - loss_r <= threshold:
        count += 1
        if count >= patience:
            break
        else:
            loss_f = loss_r
    else:
        loss_f = loss_r
# Out:
# Epoch 1/3
# 1/1 [==============================] - 1s 549ms/step - loss: 6.4731 - accuracy: 0.0556 - val_loss: 6.5486 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 1s 518ms/step - loss: 6.4186 - accuracy: 0.0000e+00 - val_loss: 6.6048 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 480ms/step - loss: 6.3226 - accuracy: 0.0000e+00 - val_loss: 6.7545 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 479ms/step - loss: 6.3890 - accuracy: 0.0556 - val_loss: 6.3454 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 448ms/step - loss: 6.3130 - accuracy: 0.1111 - val_loss: 6.3440 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 484ms/step - loss: 6.2277 - accuracy: 0.0556 - val_loss: 6.3764 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 470ms/step - loss: 6.2502 - accuracy: 0.0000e+00 - val_loss: 6.2508 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 478ms/step - loss: 6.1572 - accuracy: 0.1111 - val_loss: 6.2868 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 483ms/step - loss: 6.1820 - accuracy: 0.0000e+00 - val_loss: 6.2849 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 530ms/step - loss: 6.1513 - accuracy: 0.0556 - val_loss: 6.1536 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 495ms/step - loss: 6.1449 - accuracy: 0.0000e+00 - val_loss: 6.1483 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 476ms/step - loss: 6.0477 - accuracy: 0.1111 - val_loss: 6.2017 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 487ms/step - loss: 6.0902 - accuracy: 0.0000e+00 - val_loss: 6.0509 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.9987 - accuracy: 0.2222 - val_loss: 6.0949 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 450ms/step - loss: 5.9089 - accuracy: 0.2222 - val_loss: 6.2349 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 475ms/step - loss: 6.0092 - accuracy: 0.0556 - val_loss: 6.1220 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 449ms/step - loss: 6.0399 - accuracy: 0.0000e+00 - val_loss: 6.0924 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 449ms/step - loss: 5.8914 - accuracy: 0.0556 - val_loss: 6.1842 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 470ms/step - loss: 5.9694 - accuracy: 0.0556 - val_loss: 5.9438 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.8884 - accuracy: 0.1667 - val_loss: 5.9711 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 446ms/step - loss: 5.8012 - accuracy: 0.1111 - val_loss: 6.0737 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 475ms/step - loss: 5.8676 - accuracy: 0.0000e+00 - val_loss: 5.9249 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 452ms/step - loss: 5.8163 - accuracy: 0.0000e+00 - val_loss: 5.9875 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 451ms/step - loss: 5.7184 - accuracy: 0.2222 - val_loss: 6.1367 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 485ms/step - loss: 5.8228 - accuracy: 0.0000e+00 - val_loss: 5.8788 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 448ms/step - loss: 5.6129 - accuracy: 0.2222 - val_loss: 6.0784 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 446ms/step - loss: 5.5983 - accuracy: 0.2222 - val_loss: 6.2933 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 473ms/step - loss: 6.0135 - accuracy: 0.0000e+00 - val_loss: 5.8480 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 451ms/step - loss: 5.6273 - accuracy: 0.2222 - val_loss: 5.9337 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 452ms/step - loss: 5.5479 - accuracy: 0.1111 - val_loss: 6.0893 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 472ms/step - loss: 5.6735 - accuracy: 0.0000e+00 - val_loss: 5.7337 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.6371 - accuracy: 0.0556 - val_loss: 5.8382 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.5220 - accuracy: 0.0556 - val_loss: 5.9624 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 493ms/step - loss: 5.6498 - accuracy: 0.1667 - val_loss: 5.6341 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 454ms/step - loss: 5.4909 - accuracy: 0.1111 - val_loss: 5.7039 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 450ms/step - loss: 5.3532 - accuracy: 0.1667 - val_loss: 5.9276 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 514ms/step - loss: 5.7016 - accuracy: 0.1111 - val_loss: 5.5664 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 450ms/step - loss: 5.5055 - accuracy: 0.1667 - val_loss: 5.6221 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 448ms/step - loss: 5.4087 - accuracy: 0.2222 - val_loss: 5.7025 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 477ms/step - loss: 5.4001 - accuracy: 0.1111 - val_loss: 5.6022 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 452ms/step - loss: 5.4145 - accuracy: 0.1667 - val_loss: 5.6873 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 454ms/step - loss: 5.1978 - accuracy: 0.2778 - val_loss: 6.0443 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 470ms/step - loss: 5.3800 - accuracy: 0.1111 - val_loss: 5.2938 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.2734 - accuracy: 0.0556 - val_loss: 5.4835 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 447ms/step - loss: 5.3499 - accuracy: 0.1111 - val_loss: 5.5527 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 475ms/step - loss: 5.3173 - accuracy: 0.1111 - val_loss: 5.2856 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 451ms/step - loss: 5.2698 - accuracy: 0.1111 - val_loss: 5.4148 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 452ms/step - loss: 5.0936 - accuracy: 0.2222 - val_loss: 5.6589 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 492ms/step - loss: 5.2628 - accuracy: 0.1111 - val_loss: 5.1358 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 451ms/step - loss: 5.1045 - accuracy: 0.1111 - val_loss: 5.2281 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 449ms/step - loss: 5.1230 - accuracy: 0.1111 - val_loss: 5.3799 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 476ms/step - loss: 5.2789 - accuracy: 0.1111 - val_loss: 5.0267 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 450ms/step - loss: 4.8047 - accuracy: 0.3333 - val_loss: 5.0164 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 450ms/step - loss: 5.0471 - accuracy: 0.1667 - val_loss: 5.1508 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 0s 474ms/step - loss: 4.8108 - accuracy: 0.3333 - val_loss: 5.1079 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 449ms/step - loss: 4.7821 - accuracy: 0.1667 - val_loss: 5.1965 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 450ms/step - loss: 4.6464 - accuracy: 0.4444 - val_loss: 5.3825 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 475ms/step - loss: 4.4612 - accuracy: 0.4444 - val_loss: 5.2877 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 453ms/step - loss: 4.5953 - accuracy: 0.4444 - val_loss: 5.1991 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 452ms/step - loss: 4.6827 - accuracy: 0.1111 - val_loss: 5.3954 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 493ms/step - loss: 4.5895 - accuracy: 0.3333 - val_loss: 4.5081 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 450ms/step - loss: 4.7394 - accuracy: 0.1111 - val_loss: 4.7650 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 450ms/step - loss: 4.4457 - accuracy: 0.2222 - val_loss: 4.8904 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 475ms/step - loss: 4.0858 - accuracy: 0.5000 - val_loss: 4.5159 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 455ms/step - loss: 4.6531 - accuracy: 0.3889 - val_loss: 4.9294 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 455ms/step - loss: 4.3438 - accuracy: 0.3889 - val_loss: 5.3947 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 476ms/step - loss: 5.0694 - accuracy: 0.1111 - val_loss: 4.5169 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 451ms/step - loss: 4.4249 - accuracy: 0.3889 - val_loss: 4.4655 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 449ms/step - loss: 4.0171 - accuracy: 0.3333 - val_loss: 4.6324 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 476ms/step - loss: 4.6191 - accuracy: 0.2778 - val_loss: 4.3696 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 453ms/step - loss: 4.2989 - accuracy: 0.4444 - val_loss: 4.6160 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 453ms/step - loss: 4.0758 - accuracy: 0.4444 - val_loss: 4.7321 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 492ms/step - loss: 4.0207 - accuracy: 0.3889 - val_loss: 4.6266 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 449ms/step - loss: 4.1872 - accuracy: 0.2778 - val_loss: 4.7532 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 455ms/step - loss: 3.8678 - accuracy: 0.5556 - val_loss: 4.8056 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 0s 479ms/step - loss: 4.2920 - accuracy: 0.1667 - val_loss: 4.4434 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 457ms/step - loss: 3.6482 - accuracy: 0.5556 - val_loss: 4.6465 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 456ms/step - loss: 4.0936 - accuracy: 0.3889 - val_loss: 4.6704 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 0s 473ms/step - loss: 4.6336 - accuracy: 0.2222 - val_loss: 3.9768 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 450ms/step - loss: 4.3290 - accuracy: 0.3333 - val_loss: 3.8039 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 472ms/step - loss: 3.8990 - accuracy: 0.5556 - val_loss: 3.7858 - val_accuracy: 0.3750
# Epoch 1/3
# 1/1 [==============================] - 0s 497ms/step - loss: 4.1234 - accuracy: 0.3889 - val_loss: 3.5385 - val_accuracy: 0.6250
# Epoch 2/3
# 1/1 [==============================] - 0s 469ms/step - loss: 3.6422 - accuracy: 0.5000 - val_loss: 3.8470 - val_accuracy: 0.5000
# Epoch 3/3
# 1/1 [==============================] - 0s 471ms/step - loss: 3.6752 - accuracy: 0.3333 - val_loss: 3.9437 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 502ms/step - loss: 4.1488 - accuracy: 0.2778 - val_loss: 4.2761 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 460ms/step - loss: 3.7989 - accuracy: 0.5000 - val_loss: 4.2353 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 461ms/step - loss: 3.6649 - accuracy: 0.3889 - val_loss: 4.5233 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 488ms/step - loss: 3.6642 - accuracy: 0.6111 - val_loss: 3.9945 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 465ms/step - loss: 3.4425 - accuracy: 0.5000 - val_loss: 4.0881 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 469ms/step - loss: 3.3067 - accuracy: 0.6667 - val_loss: 4.3407 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 492ms/step - loss: 6.0221 - accuracy: 0.0556 - val_loss: 5.2592 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 467ms/step - loss: 5.1481 - accuracy: 0.1667 - val_loss: 5.2899 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 467ms/step - loss: 5.0972 - accuracy: 0.0556 - val_loss: 5.3349 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 487ms/step - loss: 5.1141 - accuracy: 0.0556 - val_loss: 5.1690 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 5.1533 - accuracy: 0.0000e+00 - val_loss: 5.1929 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 472ms/step - loss: 5.0792 - accuracy: 0.0556 - val_loss: 5.2289 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 507ms/step - loss: 5.0972 - accuracy: 0.1111 - val_loss: 5.2375 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 473ms/step - loss: 5.0850 - accuracy: 0.0556 - val_loss: 5.3342 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 5.0012 - accuracy: 0.0556 - val_loss: 5.4085 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 0s 497ms/step - loss: 4.9514 - accuracy: 0.1667 - val_loss: 5.1666 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 476ms/step - loss: 4.9372 - accuracy: 0.0556 - val_loss: 5.2641 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 4.8657 - accuracy: 0.1111 - val_loss: 5.3439 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 4.9724 - accuracy: 0.0556 - val_loss: 5.1243 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 473ms/step - loss: 4.8373 - accuracy: 0.1111 - val_loss: 5.2169 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 4.5921 - accuracy: 0.3333 - val_loss: 5.4315 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 501ms/step - loss: 4.9585 - accuracy: 0.0556 - val_loss: 4.8474 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 480ms/step - loss: 4.6996 - accuracy: 0.2222 - val_loss: 4.9985 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 473ms/step - loss: 4.8088 - accuracy: 0.2222 - val_loss: 5.0658 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 502ms/step - loss: 5.0332 - accuracy: 0.1111 - val_loss: 5.0107 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 471ms/step - loss: 4.9196 - accuracy: 0.0556 - val_loss: 5.0753 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 472ms/step - loss: 4.6988 - accuracy: 0.3333 - val_loss: 5.3249 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 504ms/step - loss: 4.8729 - accuracy: 0.1667 - val_loss: 4.8774 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 471ms/step - loss: 4.6175 - accuracy: 0.2222 - val_loss: 4.9786 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 469ms/step - loss: 4.4169 - accuracy: 0.2222 - val_loss: 5.3142 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 4.9837 - accuracy: 0.1667 - val_loss: 4.8875 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 473ms/step - loss: 4.4911 - accuracy: 0.2778 - val_loss: 5.0118 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 477ms/step - loss: 4.2219 - accuracy: 0.3333 - val_loss: 5.2548 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 1s 501ms/step - loss: 4.7576 - accuracy: 0.2222 - val_loss: 4.6653 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 478ms/step - loss: 4.3798 - accuracy: 0.4444 - val_loss: 4.8034 - val_accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 477ms/step - loss: 4.1482 - accuracy: 0.3889 - val_loss: 4.9278 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 1s 514ms/step - loss: 4.1615 - accuracy: 0.2222 - val_loss: 4.5702 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 474ms/step - loss: 4.3283 - accuracy: 0.2778 - val_loss: 4.7143 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 475ms/step - loss: 4.2175 - accuracy: 0.1111 - val_loss: 4.9720 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 497ms/step - loss: 3.9581 - accuracy: 0.3889 - val_loss: 4.3410 - val_accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 479ms/step - loss: 4.0016 - accuracy: 0.2222 - val_loss: 4.6013 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 473ms/step - loss: 3.9100 - accuracy: 0.5000 - val_loss: 5.0666 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 498ms/step - loss: 3.4725 - accuracy: 0.4444 - val_loss: 5.4925 - val_accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 468ms/step - loss: 3.8871 - accuracy: 0.2778 - val_loss: 5.4844 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 468ms/step - loss: 3.2606 - accuracy: 0.6111 - val_loss: 6.0694 - val_accuracy: 0.0000e+00
# Epoch 1/3
# 1/1 [==============================] - 0s 499ms/step - loss: 4.2831 - accuracy: 0.3889 - val_loss: 4.1796 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 4.0401 - accuracy: 0.3889 - val_loss: 4.1065 - val_accuracy: 0.1250
# Epoch 3/3
# 1/1 [==============================] - 0s 478ms/step - loss: 3.9368 - accuracy: 0.3889 - val_loss: 4.2163 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 1s 514ms/step - loss: 4.7856 - accuracy: 0.1111 - val_loss: 3.9712 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 471ms/step - loss: 3.7180 - accuracy: 0.3889 - val_loss: 4.0208 - val_accuracy: 0.2500
# Epoch 3/3
# 1/1 [==============================] - 0s 478ms/step - loss: 3.9635 - accuracy: 0.3889 - val_loss: 4.2576 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 1s 502ms/step - loss: 4.0207 - accuracy: 0.3889 - val_loss: 3.5295 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 474ms/step - loss: 3.5630 - accuracy: 0.5556 - val_loss: 3.5559 - val_accuracy: 0.5000
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 3.6738 - accuracy: 0.5000 - val_loss: 3.8682 - val_accuracy: 0.3750
# Epoch 1/3
# 1/1 [==============================] - 0s 494ms/step - loss: 4.3104 - accuracy: 0.2778 - val_loss: 3.8400 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 3.4614 - accuracy: 0.6111 - val_loss: 3.8701 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 476ms/step - loss: 3.1978 - accuracy: 0.5556 - val_loss: 4.0900 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 0s 496ms/step - loss: 3.9253 - accuracy: 0.3333 - val_loss: 3.3139 - val_accuracy: 0.6250
# Epoch 2/3
# 1/1 [==============================] - 0s 473ms/step - loss: 3.5184 - accuracy: 0.5556 - val_loss: 3.2338 - val_accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 475ms/step - loss: 3.7625 - accuracy: 0.4444 - val_loss: 3.5660 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 514ms/step - loss: 4.2628 - accuracy: 0.3333 - val_loss: 3.9661 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 475ms/step - loss: 3.7000 - accuracy: 0.3889 - val_loss: 3.9976 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 473ms/step - loss: 3.4237 - accuracy: 0.5000 - val_loss: 4.0512 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 3.8242 - accuracy: 0.4444 - val_loss: 3.4288 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 479ms/step - loss: 3.2136 - accuracy: 0.6111 - val_loss: 3.6842 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 480ms/step - loss: 3.2630 - accuracy: 0.3889 - val_loss: 3.8470 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 3.5736 - accuracy: 0.5000 - val_loss: 3.2393 - val_accuracy: 0.5000
# Epoch 2/3
# 1/1 [==============================] - 0s 474ms/step - loss: 2.7242 - accuracy: 0.8333 - val_loss: 3.3610 - val_accuracy: 0.5000
# Epoch 3/3
# 1/1 [==============================] - 0s 478ms/step - loss: 2.7081 - accuracy: 0.6111 - val_loss: 3.6721 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 1s 501ms/step - loss: 3.2118 - accuracy: 0.6111 - val_loss: 2.9467 - val_accuracy: 0.8750
# Epoch 2/3
# 1/1 [==============================] - 0s 472ms/step - loss: 3.2137 - accuracy: 0.5000 - val_loss: 2.9030 - val_accuracy: 0.7500
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 2.5957 - accuracy: 0.7778 - val_loss: 3.0440 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 512ms/step - loss: 3.4890 - accuracy: 0.5556 - val_loss: 2.9913 - val_accuracy: 0.6250
# Epoch 2/3
# 1/1 [==============================] - 0s 474ms/step - loss: 2.9129 - accuracy: 0.6111 - val_loss: 3.1425 - val_accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.7084 - accuracy: 0.6667 - val_loss: 3.3193 - val_accuracy: 0.2500
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 3.0899 - accuracy: 0.4444 - val_loss: 3.1186 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.9214 - accuracy: 0.5556 - val_loss: 3.1526 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 479ms/step - loss: 2.8104 - accuracy: 0.7222 - val_loss: 3.1666 - val_accuracy: 0.3750
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 3.9743 - accuracy: 0.2778 - val_loss: 3.3100 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.9905 - accuracy: 0.4444 - val_loss: 3.0091 - val_accuracy: 0.5000
# Epoch 3/3
# 1/1 [==============================] - 0s 474ms/step - loss: 2.6050 - accuracy: 0.8333 - val_loss: 3.5868 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 1s 502ms/step - loss: 3.2758 - accuracy: 0.5556 - val_loss: 2.3870 - val_accuracy: 1.0000
# Epoch 2/3
# 1/1 [==============================] - 0s 479ms/step - loss: 2.7861 - accuracy: 0.5556 - val_loss: 2.5658 - val_accuracy: 0.7500
# Epoch 3/3
# 1/1 [==============================] - 0s 479ms/step - loss: 2.9014 - accuracy: 0.6667 - val_loss: 2.3803 - val_accuracy: 0.8750
# Epoch 1/3
# 1/1 [==============================] - 1s 522ms/step - loss: 3.0464 - accuracy: 0.6111 - val_loss: 3.0249 - val_accuracy: 0.6250
# Epoch 2/3
# 1/1 [==============================] - 0s 473ms/step - loss: 2.4261 - accuracy: 0.7778 - val_loss: 3.0080 - val_accuracy: 0.5000
# Epoch 3/3
# 1/1 [==============================] - 0s 471ms/step - loss: 2.6013 - accuracy: 0.6667 - val_loss: 3.2820 - val_accuracy: 0.5000
# Epoch 1/3
# 1/1 [==============================] - 0s 494ms/step - loss: 2.9503 - accuracy: 0.6667 - val_loss: 2.2140 - val_accuracy: 0.8750
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.4297 - accuracy: 0.7778 - val_loss: 2.2816 - val_accuracy: 0.8750
# Epoch 3/3
# 1/1 [==============================] - 0s 478ms/step - loss: 2.6157 - accuracy: 0.6667 - val_loss: 2.4789 - val_accuracy: 0.7500
# Epoch 1/3
# 1/1 [==============================] - 0s 499ms/step - loss: 5.0086 - accuracy: 0.2222 - val_loss: 3.3722 - val_accuracy: 0.8750
# Epoch 2/3
# 1/1 [==============================] - 0s 475ms/step - loss: 2.7908 - accuracy: 0.7778 - val_loss: 3.0505 - val_accuracy: 0.7500
# Epoch 3/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.7011 - accuracy: 0.7222 - val_loss: 3.0440 - val_accuracy: 0.7500
# Epoch 1/3
# 1/1 [==============================] - 1s 500ms/step - loss: 2.6824 - accuracy: 0.7778 - val_loss: 2.5553 - val_accuracy: 0.8750
# Epoch 2/3
# 1/1 [==============================] - 0s 475ms/step - loss: 2.3762 - accuracy: 0.7222 - val_loss: 2.8542 - val_accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 478ms/step - loss: 2.3642 - accuracy: 0.8333 - val_loss: 2.8577 - val_accuracy: 0.6250
# Epoch 1/3
# 1/1 [==============================] - 1s 516ms/step - loss: 3.7640 - accuracy: 0.6111 - val_loss: 4.2933 - val_accuracy: 0.0000e+00
# Epoch 2/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.4121 - accuracy: 0.8333 - val_loss: 4.5954 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 472ms/step - loss: 2.5470 - accuracy: 0.7778 - val_loss: 4.6933 - val_accuracy: 0.1250
# Epoch 1/3
# 1/1 [==============================] - 0s 499ms/step - loss: 3.7262 - accuracy: 0.4444 - val_loss: 2.9521 - val_accuracy: 0.7500
# Epoch 2/3
# 1/1 [==============================] - 0s 472ms/step - loss: 3.2053 - accuracy: 0.5000 - val_loss: 2.8530 - val_accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 480ms/step - loss: 3.1175 - accuracy: 0.3889 - val_loss: 3.0148 - val_accuracy: 0.6250
# Epoch 1/3
# 1/1 [==============================] - 1s 531ms/step - loss: 3.3143 - accuracy: 0.6111 - val_loss: 3.2529 - val_accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 476ms/step - loss: 2.9318 - accuracy: 0.5000 - val_loss: 3.3626 - val_accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 477ms/step - loss: 2.5144 - accuracy: 0.7222 - val_loss: 3.5767 - val_accuracy: 0.3750
# Epoch 1/3
# 1/1 [==============================] - 1s 501ms/step - loss: 3.5460 - accuracy: 0.5000 - val_loss: 2.6433 - val_accuracy: 0.8750
# Epoch 2/3
# 1/1 [==============================] - 0s 474ms/step - loss: 2.9821 - accuracy: 0.6667 - val_loss: 2.3777 - val_accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 475ms/step - loss: 3.0198 - accuracy: 0.6667 - val_loss: 2.6707 - val_accuracy: 0.6250

# %%
plt.plot(history_dict['acc'], color='r', label='training')
plt.plot(history_dict['val_acc'], color='b', label='validation')
plt.legend()
plt.savefig(f'../data/models/{model_name}_acc.jpg')
plt.show()

# %%
plt.plot(history_dict['loss'], color='r', label='training')
plt.plot(history_dict['val_loss'], color='b', label='validation')
plt.legend()
plt.savefig(f'../data/models/{model_name}_loss.jpg')
plt.show()

# %%
test_dir = '../data/test'
test_list = os.listdir(test_dir)
y_pred = list()
y_true = list()
acc_list = list()

for folder in test_list:
    test_x_data = list()
    test_t_data = list()
    for n in range(num_class):
        file_dir = os.path.join(test_dir, (folder+'/'+str(n)))
        file_list = os.listdir(os.path.join(test_dir, (folder+'/'+str(n))))
        temp_data = list()
        for file in file_list:
            img = cv2.imread(os.path.join(file_dir, file))
            img = np.array(img)
            # 정규화
            img = img/255
            temp_data.append(img)
        temp_data = np.array(temp_data)
        test_x_data.append(temp_data)
        test_t_data.append(n)

    # 리스트인 batch_x_data를 ndarray로
    test_x_data = np.array(test_x_data)
    test_t_data = np.array(test_t_data)

    # 축변경
    test_x_data = np.swapaxes(test_x_data,1,2)
    test_x_data = np.swapaxes(test_x_data,2,3)

    # data shuffle
    random.shuffle(shuffle_list)

    test_x_data = test_x_data[shuffle_list]
    test_t_data = test_t_data[shuffle_list]

    # one_hot_encording
    test_t_data = np.array(test_t_data)
    test_t_data = pd.DataFrame(test_t_data, columns=['t'])
    test_t_data = pd.get_dummies(test_t_data['t'])

    result = model.predict(test_x_data)
    y_pred.append(np.argmax(result, axis=1))
    y_true.append(np.argmax(test_t_data.values, axis=1))

    result = model.evaluate(x=test_x_data, y=test_t_data.values)
    acc_list.append(np.round(result, 4))
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4123 - accuracy: 0.4615
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3751 - accuracy: 0.3462
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2715 - accuracy: 0.3846

# %%
y_pred = np.array(y_pred)
print(y_pred.ravel())
y_true = np.array(y_true)
print(y_true.ravel())

result = np.equal(y_pred.ravel(), y_true.ravel())
print(np.sum(result)/len(result))

# %%
acc_list = np.array(acc_list)
print(np.round(np.mean(acc_list, axis=0), 4))

# %%
result = model.evaluate(x=test_x_data, y=test_t_data.values)
print(np.round(result, 4))

# %%
model.save(f'../data/models/{model_name}.h5')
